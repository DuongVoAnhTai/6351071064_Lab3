# %% [markdown]
# # Gom cụm dữ liệu MNIST với thuật toán K-Means
# Notebook này thực hiện gom cụm dữ liệu MNIST bằng thuật toán K-Means và so sánh kết quả với nhãn thực tế.

# %% [markdown]
# ## 1. Import các thư viện cần thiết

# %%
STUDENT="Dương Võ Anh Tài - 6351071064"

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_openml
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, adjusted_rand_score, normalized_mutual_info_score, silhouette_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
from scipy.optimize import linear_sum_assignment

print(STUDENT)
print("Đã import thành công các thư viện!")
# Out:
# Dương Võ Anh Tài - 6351071064
# Đã import thành công các thư viện!

# %% [markdown]
# ## 2. Tải và chuẩn bị dữ liệu MNIST

# %%
print(STUDENT)

# Tải dữ liệu MNIST
print("Đang tải dữ liệu MNIST...")
mnist = fetch_openml('mnist_784', version=1, parser='auto')
X, y = mnist.data, mnist.target

# Chuyển đổi nhãn sang kiểu int
y = y.astype(int)

# Sử dụng subset để giảm thời gian tính toán (có thể điều chỉnh)
n_samples = 10000  # Sử dụng 10,000 mẫu
indices = np.random.choice(len(X), n_samples, replace=False)
X_sample = X.iloc[indices] if hasattr(X, 'iloc') else X[indices]
y_sample = y.iloc[indices] if hasattr(y, 'iloc') else y[indices]

# Chuẩn hóa dữ liệu
X_sample = X_sample / 255.0

print(f"Kích thước dữ liệu: {X_sample.shape}")
print(f"Số lượng nhãn: {len(np.unique(y_sample))}")
print(f"Phân bố các nhãn:\n{pd.Series(y_sample).value_counts().sort_index()}")
# Out:
# Dương Võ Anh Tài - 6351071064
# Đang tải dữ liệu MNIST...
# Kích thước dữ liệu: (10000, 784)
# Số lượng nhãn: 10
# Phân bố các nhãn:
# class
# 0     997
# 1    1136
# 2    1001
# 3    1030
# 4     933
# 5     934
# 6     941
# 7    1062
# 8     980
# 9     986
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Hiển thị một số ví dụ từ dữ liệu

# %%
print(STUDENT)

# Hiển thị 10 ảnh mẫu
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
for i, ax in enumerate(axes.flat):
    if hasattr(X_sample, 'iloc'):
        image = X_sample.iloc[i].values.reshape(28, 28)
    else:
        image = X_sample[i].reshape(28, 28)
    ax.imshow(image, cmap='gray')
    ax.set_title(f'Nhãn: {y_sample.iloc[i] if hasattr(y_sample, "iloc") else y_sample[i]}')
    ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Dương Võ Anh Tài - 6351071064

# %% [markdown]
# ## 4. Thực hiện thuật toán K-Means

# %%
print(STUDENT)

# Số cụm bằng số chữ số (0-9)
n_clusters = 10

print(f"Đang thực hiện K-Means với {n_clusters} cụm...")
kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10, max_iter=300, verbose=1)
cluster_labels = kmeans.fit_predict(X_sample)

print("\nHoàn thành gom cụm!")
print(f"Inertia (tổng bình phương khoảng cách): {kmeans.inertia_:.2f}")
# Out:
# Dương Võ Anh Tài - 6351071064
# Đang thực hiện K-Means với 10 cụm...
# Initialization complete
# Iteration 0, inertia 653950.8405228782.
# Iteration 1, inertia 409542.77049624297.
# Iteration 2, inertia 399162.7815292129.
# Iteration 3, inertia 395934.2558235333.
# Iteration 4, inertia 394882.1895895085.
# Iteration 5, inertia 394462.29127318226.
# Iteration 6, inertia 394218.8329410298.
# Iteration 7, inertia 394077.5159207297.
# Iteration 8, inertia 394002.010493739.
# Iteration 9, inertia 393960.36637355696.
# Iteration 10, inertia 393936.09806062863.
# Iteration 11, inertia 393915.5652169755.
# Iteration 12, inertia 393900.7059426641.
# Iteration 13, inertia 393886.75255176576.
# Iteration 14, inertia 393877.85892158485.
# Iteration 15, inertia 393872.7262363692.
# Iteration 16, inertia 393868.09260013455.
# Iteration 17, inertia 393865.5588386757.
# Iteration 18, inertia 393863.51387646026.
# Iteration 19, inertia 393862.18264042155.
# Iteration 20, inertia 393860.88343118277.
# Iteration 21, inertia 393860.4431403975.
# Iteration 22, inertia 393860.2784259499.
# Converged at iteration 22: strict convergence.
# Initialization complete
# Iteration 0, inertia 654833.21707036.
# Iteration 1, inertia 416272.48577621457.
# Iteration 2, inertia 404453.54991053103.
# Iteration 3, inertia 398880.5897966935.
# Iteration 4, inertia 396917.8368882055.
# Iteration 5, inertia 396239.92696029955.
# Iteration 6, inertia 395962.79297255666.
# Iteration 7, inertia 395821.2074743726.
# Iteration 8, inertia 395735.08269040234.
# Iteration 9, inertia 395678.5452547474.
# Iteration 10, inertia 395644.4314773261.
# Iteration 11, inertia 395624.22323488607.
# Iteration 12, inertia 395599.9701407827.
# Iteration 13, inertia 395561.89221962576.
# Iteration 14, inertia 395513.5621299892.
# Iteration 15, inertia 395467.94082117104.
# Iteration 16, inertia 395419.0132584791.
# Iteration 17, inertia 395359.9885183499.
# Iteration 18, inertia 395253.5493596318.
# Iteration 19, inertia 395110.57727507834.
# Iteration 20, inertia 394952.59610518516.
# Iteration 21, inertia 394812.3952579707.
# Iteration 22, inertia 394651.2237017115.
# Iteration 23, inertia 394510.7500096086.
# Iteration 24, inertia 394406.95063882775.
# Iteration 25, inertia 394318.1145489113.
# Iteration 26, inertia 394244.72034340334.
# Iteration 27, inertia 394194.2528511793.
# Iteration 28, inertia 394176.2164021781.
# Iteration 29, inertia 394166.6576361756.
# Iteration 30, inertia 394160.1536196434.
# Iteration 31, inertia 394153.6865626771.
# Iteration 32, inertia 394147.4787931713.
# Iteration 33, inertia 394144.2572025713.
# Iteration 34, inertia 394141.6972702605.
# Iteration 35, inertia 394138.50501595694.
# Iteration 36, inertia 394135.2678419988.
# Iteration 37, inertia 394128.94612052443.
# Iteration 38, inertia 394120.79594770016.
# Iteration 39, inertia 394116.32616659923.
# Iteration 40, inertia 394112.8749581247.
# Iteration 41, inertia 394109.843415917.
# Iteration 42, inertia 394107.48629843985.
# Iteration 43, inertia 394104.6800022545.
# Iteration 44, inertia 394101.8275460109.
# Iteration 45, inertia 394098.97121529444.
# Iteration 46, inertia 394096.73266503034.
# Iteration 47, inertia 394096.123719037.
# Iteration 48, inertia 394095.43648984446.
# Iteration 49, inertia 394094.7713486788.
# Iteration 50, inertia 394094.13104758324.
# Iteration 51, inertia 394093.8832828145.
# Iteration 52, inertia 394093.742154271.
# Iteration 53, inertia 394093.45322905114.
# Iteration 54, inertia 394093.4011726895.
# Converged at iteration 54: strict convergence.
# Initialization complete
# Iteration 0, inertia 644916.2061207248.
# Iteration 1, inertia 414942.2450086392.
# Iteration 2, inertia 406272.0019987082.
# Iteration 3, inertia 402405.10926130955.
# Iteration 4, inertia 400407.8679898643.
# Iteration 5, inertia 399157.55931044597.
# Iteration 6, inertia 398334.9979871363.
# Iteration 7, inertia 397706.71964971663.
# Iteration 8, inertia 397247.18832417653.
# Iteration 9, inertia 396954.90931670583.
# Iteration 10, inertia 396770.9493980388.
# Iteration 11, inertia 396643.8952689968.
# Iteration 12, inertia 396519.13494482904.
# Iteration 13, inertia 396376.80730486684.
# Iteration 14, inertia 396230.6406859969.
# Iteration 15, inertia 396096.8025343022.
# Iteration 16, inertia 395961.10158455884.
# Iteration 17, inertia 395824.02289491595.
# Iteration 18, inertia 395703.4536207784.
# Iteration 19, inertia 395617.1965787125.
# Iteration 20, inertia 395555.6654707248.
# Iteration 21, inertia 395505.6066363011.
# Iteration 22, inertia 395467.4232431497.
# Iteration 23, inertia 395444.1085538093.
# Iteration 24, inertia 395415.7472946432.
# Iteration 25, inertia 395383.61051679665.
# Iteration 26, inertia 395361.83630319824.
# Iteration 27, inertia 395345.9278014784.
# Iteration 28, inertia 395334.939135671.
# Iteration 29, inertia 395326.18921542866.
# Iteration 30, inertia 395316.8575429594.
# Iteration 31, inertia 395307.6069019217.
# Iteration 32, inertia 395286.6855690923.
# Iteration 33, inertia 395263.27421673876.
# Iteration 34, inertia 395238.7898646327.
# Iteration 35, inertia 395223.71765549807.
# Iteration 36, inertia 395217.47557433037.
# Iteration 37, inertia 395213.29652545083.
# Iteration 38, inertia 395209.40575208224.
# Iteration 39, inertia 395204.107805667.
# Iteration 40, inertia 395200.04013585846.
# Iteration 41, inertia 395195.2403017544.
# Iteration 42, inertia 395191.1818595121.
# Iteration 43, inertia 395187.26360551507.
# Iteration 44, inertia 395182.34553756576.
# Iteration 45, inertia 395179.3627357737.
# Iteration 46, inertia 395176.9350475677.
# Iteration 47, inertia 395174.5842933244.
# Iteration 48, inertia 395173.2706164051.
# Iteration 49, inertia 395171.2151266658.
# Iteration 50, inertia 395169.7782638394.
# Iteration 51, inertia 395167.2492882651.
# Iteration 52, inertia 395164.899838723.
# Iteration 53, inertia 395163.49629207415.
# Iteration 54, inertia 395162.3014831309.
# Iteration 55, inertia 395161.42632467207.
# Iteration 56, inertia 395159.00109488587.
# Iteration 57, inertia 395151.34442429006.
# Iteration 58, inertia 395141.4006482633.
# Iteration 59, inertia 395127.3203761008.
# Iteration 60, inertia 395107.11914316594.
# Iteration 61, inertia 395084.10612300923.
# Iteration 62, inertia 395071.2353836024.
# Iteration 63, inertia 395063.15531781333.
# Iteration 64, inertia 395054.02736159385.
# Iteration 65, inertia 395039.99299376406.
# Iteration 66, inertia 395025.58752041886.
# Iteration 67, inertia 395006.17676160333.
# Iteration 68, inertia 394982.4033600806.
# Iteration 69, inertia 394957.7349337577.
# Iteration 70, inertia 394934.3061171901.
# Iteration 71, inertia 394916.75739049946.
# Iteration 72, inertia 394898.90606021945.
# Iteration 73, inertia 394880.1097510373.
# Iteration 74, inertia 394870.49727194844.
# Iteration 75, inertia 394864.8580329594.
# Iteration 76, inertia 394860.6940182244.
# Iteration 77, inertia 394853.06837958546.
# Iteration 78, inertia 394843.1577054346.
# Iteration 79, inertia 394833.9237088624.
# Iteration 80, inertia 394826.96477258403.
# Iteration 81, inertia 394815.976554888.
# Iteration 82, inertia 394807.0669899624.
# Iteration 83, inertia 394798.4857723306.
# Iteration 84, inertia 394794.7188689261.
# Iteration 85, inertia 394791.6651116245.
# Iteration 86, inertia 394789.01854794176.
# Iteration 87, inertia 394787.3485894008.
# Iteration 88, inertia 394785.9681070404.
# Iteration 89, inertia 394784.85991787666.
# Iteration 90, inertia 394783.1477124163.
# Iteration 91, inertia 394781.58392509376.
# Iteration 92, inertia 394780.9124190985.
# Iteration 93, inertia 394780.8139665344.
# Converged at iteration 93: strict convergence.
# Initialization complete
# Iteration 0, inertia 637474.2985005786.
# Iteration 1, inertia 411774.26818199427.
# Iteration 2, inertia 400976.910210893.
# Iteration 3, inertia 396632.9458133204.
# Iteration 4, inertia 395344.6185731792.
# Iteration 5, inertia 394845.17071704805.
# Iteration 6, inertia 394618.1644560901.
# Iteration 7, inertia 394470.080331992.
# Iteration 8, inertia 394359.01960151043.
# Iteration 9, inertia 394280.0163283636.
# Iteration 10, inertia 394220.0664487743.
# Iteration 11, inertia 394168.2319585923.
# Iteration 12, inertia 394084.35291885084.
# Iteration 13, inertia 393965.4445706091.
# Iteration 14, inertia 393838.8261182881.
# Iteration 15, inertia 393707.356473357.
# Iteration 16, inertia 393564.7193745835.
# Iteration 17, inertia 393403.74344531755.
# Iteration 18, inertia 393223.5577064713.
# Iteration 19, inertia 393120.9644934847.
# Iteration 20, inertia 393064.5818801514.
# Iteration 21, inertia 393025.5503347547.
# Iteration 22, inertia 392998.7814789755.
# Iteration 23, inertia 392984.71537098486.
# Iteration 24, inertia 392976.87707666913.
# Iteration 25, inertia 392972.4100895005.
# Iteration 26, inertia 392970.1071655956.
# Iteration 27, inertia 392968.38603219704.
# Iteration 28, inertia 392966.9543526227.
# Iteration 29, inertia 392965.96852850966.
# Iteration 30, inertia 392965.53688447835.
# Iteration 31, inertia 392965.118589376.
# Iteration 32, inertia 392964.63086454524.
# Iteration 33, inertia 392963.8484179411.
# Iteration 34, inertia 392962.59626831533.
# Iteration 35, inertia 392962.1224642618.
# Iteration 36, inertia 392961.8211555584.
# Iteration 37, inertia 392961.16165678645.
# Iteration 38, inertia 392960.074716125.
# Iteration 39, inertia 392958.7528306348.
# Iteration 40, inertia 392958.1635245526.
# Iteration 41, inertia 392957.6144857606.
# Iteration 42, inertia 392957.1296155534.
# Iteration 43, inertia 392957.028094266.
# Iteration 44, inertia 392956.9842232161.
# Converged at iteration 44: strict convergence.
# Initialization complete
# Iteration 0, inertia 658662.0379238754.
# Iteration 1, inertia 409853.31853340805.
# Iteration 2, inertia 402589.5359682053.
# Iteration 3, inertia 399599.1901155529.
# Iteration 4, inertia 397933.68573619134.
# Iteration 5, inertia 396908.6740683697.
# Iteration 6, inertia 396367.51827459736.
# Iteration 7, inertia 396014.2980705789.
# Iteration 8, inertia 395670.859626823.
# Iteration 9, inertia 395332.41078757495.
# Iteration 10, inertia 394911.20126013196.
# Iteration 11, inertia 394552.23459165025.
# Iteration 12, inertia 394263.6903312286.
# Iteration 13, inertia 394030.19113836525.
# Iteration 14, inertia 393820.51606240304.
# Iteration 15, inertia 393560.9709098901.
# Iteration 16, inertia 393270.6433870227.
# Iteration 17, inertia 392984.6354780688.
# Iteration 18, inertia 392710.30726094526.
# Iteration 19, inertia 392454.37454132247.
# Iteration 20, inertia 392282.99318862526.
# Iteration 21, inertia 392214.2455969235.
# Iteration 22, inertia 392172.62190051767.
# Iteration 23, inertia 392146.224531513.
# Iteration 24, inertia 392128.2251069194.
# Iteration 25, inertia 392116.47370384657.
# Iteration 26, inertia 392111.5912336062.
# Iteration 27, inertia 392108.6093543584.
# Iteration 28, inertia 392105.40627294616.
# Iteration 29, inertia 392100.9362438247.
# Iteration 30, inertia 392099.8463846525.
# Iteration 31, inertia 392099.27159110556.
# Iteration 32, inertia 392098.96786676237.
# Converged at iteration 32: strict convergence.
# Initialization complete
# Iteration 0, inertia 677700.3643983058.
# Iteration 1, inertia 417257.90470818366.
# Iteration 2, inertia 405761.1590694381.
# Iteration 3, inertia 401872.7401614462.
# Iteration 4, inertia 399731.37936306687.
# Iteration 5, inertia 398616.9249549473.
# Iteration 6, inertia 397955.2748177746.
# Iteration 7, inertia 397404.8583270183.
# Iteration 8, inertia 396952.75896178145.
# Iteration 9, inertia 396620.2336107108.
# Iteration 10, inertia 396390.5609676355.
# Iteration 11, inertia 396196.793802386.
# Iteration 12, inertia 396030.87081109243.
# Iteration 13, inertia 395942.759147446.
# Iteration 14, inertia 395874.34523742605.
# Iteration 15, inertia 395823.36253361823.
# Iteration 16, inertia 395793.09451379057.
# Iteration 17, inertia 395774.4927829715.
# Iteration 18, inertia 395764.15178193536.
# Iteration 19, inertia 395759.8341612365.
# Iteration 20, inertia 395757.1941937935.
# Iteration 21, inertia 395755.8231123361.
# Iteration 22, inertia 395754.7156226136.
# Iteration 23, inertia 395753.3613714026.
# Iteration 24, inertia 395751.6708763815.
# Iteration 25, inertia 395750.78575319145.
# Iteration 26, inertia 395750.20558896346.
# Iteration 27, inertia 395750.04163087154.
# Iteration 28, inertia 395749.95537133276.
# Iteration 29, inertia 395749.8473026118.
# Iteration 30, inertia 395749.6067661792.
# Iteration 31, inertia 395749.25473937014.
# Iteration 32, inertia 395749.1767731634.
# Converged at iteration 32: strict convergence.
# Initialization complete
# Iteration 0, inertia 655834.5934948081.
# Iteration 1, inertia 419928.6663056307.
# Iteration 2, inertia 407535.3922591033.
# Iteration 3, inertia 403022.08588572807.
# Iteration 4, inertia 401405.1826751156.
# Iteration 5, inertia 400838.5430421417.
# Iteration 6, inertia 400538.17813498346.
# Iteration 7, inertia 400256.7214626685.
# Iteration 8, inertia 399837.58889432263.
# Iteration 9, inertia 399225.4820154902.
# Iteration 10, inertia 398569.05549047934.
# Iteration 11, inertia 397938.3143047035.
# Iteration 12, inertia 397421.82908596826.
# Iteration 13, inertia 397077.74990646454.
# Iteration 14, inertia 396840.65074548166.
# Iteration 15, inertia 396698.94617042737.
# Iteration 16, inertia 396630.4424877927.
# Iteration 17, inertia 396587.05515278224.
# Iteration 18, inertia 396552.1439429391.
# Iteration 19, inertia 396521.1064258371.
# Iteration 20, inertia 396490.9551536826.
# Iteration 21, inertia 396452.60460215417.
# Iteration 22, inertia 396404.12316621677.
# Iteration 23, inertia 396323.26115797344.
# Iteration 24, inertia 396194.5268233963.
# Iteration 25, inertia 396001.0009596323.
# Iteration 26, inertia 395782.9488379127.
# Iteration 27, inertia 395535.1077161306.
# Iteration 28, inertia 395296.5503739884.
# Iteration 29, inertia 395084.02859780705.
# Iteration 30, inertia 394850.8367286104.
# Iteration 31, inertia 394647.09567675844.
# Iteration 32, inertia 394507.3482056453.
# Iteration 33, inertia 394425.36858069187.
# Iteration 34, inertia 394354.6403368537.
# Iteration 35, inertia 394303.34895250126.
# Iteration 36, inertia 394250.7511509885.
# Iteration 37, inertia 394189.3200249822.
# Iteration 38, inertia 394103.6858156897.
# Iteration 39, inertia 393991.39564175496.
# Iteration 40, inertia 393812.55549674504.
# Iteration 41, inertia 393608.70229087194.
# Iteration 42, inertia 393385.78137096117.
# Iteration 43, inertia 393180.78679607593.
# Iteration 44, inertia 393055.70698038227.
# Iteration 45, inertia 392996.4924029582.
# Iteration 46, inertia 392966.39822089736.
# Iteration 47, inertia 392946.142487177.
# Iteration 48, inertia 392935.7360684636.
# Iteration 49, inertia 392928.78084981896.
# Iteration 50, inertia 392922.41250203375.
# Iteration 51, inertia 392916.85954846983.
# Iteration 52, inertia 392913.13728187303.
# Iteration 53, inertia 392910.02411044075.
# Iteration 54, inertia 392905.24025781144.
# Iteration 55, inertia 392900.03138898284.
# Iteration 56, inertia 392888.74554912804.
# Iteration 57, inertia 392869.1500262982.
# Iteration 58, inertia 392848.04541381414.
# Iteration 59, inertia 392828.20388455514.
# Iteration 60, inertia 392814.7234251801.
# Iteration 61, inertia 392802.7689483255.
# Iteration 62, inertia 392787.70507087134.
# Iteration 63, inertia 392775.1367075678.
# Iteration 64, inertia 392765.3087047768.
# Iteration 65, inertia 392752.25750395027.
# Iteration 66, inertia 392737.2106630025.
# Iteration 67, inertia 392722.3929819633.
# Iteration 68, inertia 392711.40676515776.
# Iteration 69, inertia 392696.629150948.
# Iteration 70, inertia 392685.8510493746.
# Iteration 71, inertia 392675.3178131254.
# Iteration 72, inertia 392665.57035139954.
# Iteration 73, inertia 392657.00857144524.
# Iteration 74, inertia 392649.69632301974.
# Iteration 75, inertia 392645.3367972343.
# Iteration 76, inertia 392642.8838327059.
# Iteration 77, inertia 392642.4997587407.
# Iteration 78, inertia 392642.070373724.
# Iteration 79, inertia 392641.6744665227.
# Iteration 80, inertia 392641.158964057.
# Iteration 81, inertia 392640.2658489707.
# Iteration 82, inertia 392639.54492856393.
# Iteration 83, inertia 392638.93913521885.
# Iteration 84, inertia 392638.32492786663.
# Iteration 85, inertia 392637.86858401395.
# Iteration 86, inertia 392637.60070629686.
# Iteration 87, inertia 392637.3748783665.
# Iteration 88, inertia 392637.18864053744.
# Iteration 89, inertia 392637.0052902208.
# Iteration 90, inertia 392636.3863382325.
# Iteration 91, inertia 392636.14739220747.
# Converged at iteration 91: strict convergence.
# Initialization complete
# Iteration 0, inertia 649941.6716801219.
# Iteration 1, inertia 413024.51462038304.
# Iteration 2, inertia 403328.15486323705.
# Iteration 3, inertia 400270.702041365.
# Iteration 4, inertia 398544.36788858176.
# Iteration 5, inertia 397485.406191089.
# Iteration 6, inertia 396918.6318265769.
# Iteration 7, inertia 396679.27835710155.
# Iteration 8, inertia 396547.5368089206.
# Iteration 9, inertia 396418.633081613.
# Iteration 10, inertia 396304.20112641406.
# Iteration 11, inertia 396198.30144849385.
# Iteration 12, inertia 396103.83504696866.
# Iteration 13, inertia 396002.2308755782.
# Iteration 14, inertia 395924.6034752291.
# Iteration 15, inertia 395855.1935656413.
# Iteration 16, inertia 395767.57457637915.
# Iteration 17, inertia 395649.5761206975.
# Iteration 18, inertia 395544.85189991083.
# Iteration 19, inertia 395457.8288292975.
# Iteration 20, inertia 395351.0403936027.
# Iteration 21, inertia 395254.74617922324.
# Iteration 22, inertia 395179.6487815975.
# Iteration 23, inertia 395088.94793577987.
# Iteration 24, inertia 395003.2573212585.
# Iteration 25, inertia 394916.47687030653.
# Iteration 26, inertia 394833.8884778677.
# Iteration 27, inertia 394769.03235173586.
# Iteration 28, inertia 394710.0968780787.
# Iteration 29, inertia 394671.171563896.
# Iteration 30, inertia 394641.3395569946.
# Iteration 31, inertia 394617.3642525472.
# Iteration 32, inertia 394590.4785061502.
# Iteration 33, inertia 394556.6835073639.
# Iteration 34, inertia 394526.7516094362.
# Iteration 35, inertia 394507.4005872398.
# Iteration 36, inertia 394493.53570561967.
# Iteration 37, inertia 394475.5061690259.
# Iteration 38, inertia 394455.8991490772.
# Iteration 39, inertia 394437.7691372011.
# Iteration 40, inertia 394423.8097705062.
# Iteration 41, inertia 394415.447509913.
# Iteration 42, inertia 394409.5944247913.
# Iteration 43, inertia 394406.4620588892.
# Iteration 44, inertia 394402.7550573185.
# Iteration 45, inertia 394397.86937944515.
# Iteration 46, inertia 394393.58596668317.
# Iteration 47, inertia 394391.35435537645.
# Iteration 48, inertia 394389.75476933445.
# Iteration 49, inertia 394387.12843447406.
# Iteration 50, inertia 394385.2675297642.
# Iteration 51, inertia 394383.8704763066.
# Iteration 52, inertia 394382.7214114554.
# Iteration 53, inertia 394381.58302251686.
# Iteration 54, inertia 394380.6185087747.
# Iteration 55, inertia 394380.5339913127.
# Iteration 56, inertia 394380.30590161536.
# Iteration 57, inertia 394380.01430228894.
# Iteration 58, inertia 394379.7947981019.
# Iteration 59, inertia 394379.55063913646.
# Iteration 60, inertia 394378.9438016551.
# Iteration 61, inertia 394378.1384094111.
# Iteration 62, inertia 394377.2811012671.
# Iteration 63, inertia 394376.2799561181.
# Iteration 64, inertia 394376.03648708866.
# Converged at iteration 64: strict convergence.
# Initialization complete
# Iteration 0, inertia 662398.7139715465.
# Iteration 1, inertia 412673.1938126974.
# Iteration 2, inertia 402272.268850798.
# Iteration 3, inertia 398311.106982503.
# Iteration 4, inertia 396738.6466000403.
# Iteration 5, inertia 395960.6556873259.
# Iteration 6, inertia 395597.8620339492.
# Iteration 7, inertia 395444.7865985136.
# Iteration 8, inertia 395330.74671776744.
# Iteration 9, inertia 395238.6097943834.
# Iteration 10, inertia 395157.06649794703.
# Iteration 11, inertia 395071.96396852925.
# Iteration 12, inertia 394991.4056609105.
# Iteration 13, inertia 394917.39682617.
# Iteration 14, inertia 394851.67756400106.
# Iteration 15, inertia 394793.5943110802.
# Iteration 16, inertia 394745.2993925903.
# Iteration 17, inertia 394696.03289151913.
# Iteration 18, inertia 394647.71681565576.
# Iteration 19, inertia 394607.4207103932.
# Iteration 20, inertia 394577.22409507073.
# Iteration 21, inertia 394544.49429362215.
# Iteration 22, inertia 394515.2582147486.
# Iteration 23, inertia 394482.95581999613.
# Iteration 24, inertia 394449.9633606582.
# Iteration 25, inertia 394427.3765083366.
# Iteration 26, inertia 394406.08423992374.
# Iteration 27, inertia 394385.4139963201.
# Iteration 28, inertia 394368.3199544307.
# Iteration 29, inertia 394353.4837700877.
# Iteration 30, inertia 394339.06361121126.
# Iteration 31, inertia 394329.16768384667.
# Iteration 32, inertia 394323.18398235214.
# Iteration 33, inertia 394318.37936085917.
# Iteration 34, inertia 394315.68712388736.
# Iteration 35, inertia 394311.42069414334.
# Iteration 36, inertia 394307.09267302667.
# Iteration 37, inertia 394303.91446244647.
# Iteration 38, inertia 394302.05217539216.
# Iteration 39, inertia 394300.3922394834.
# Iteration 40, inertia 394299.1341413556.
# Iteration 41, inertia 394298.75079548795.
# Iteration 42, inertia 394298.26740971644.
# Iteration 43, inertia 394297.3745036957.
# Iteration 44, inertia 394296.5357288009.
# Iteration 45, inertia 394295.9889417994.
# Iteration 46, inertia 394295.73910191853.
# Iteration 47, inertia 394295.42775701056.
# Iteration 48, inertia 394295.1156077893.
# Iteration 49, inertia 394294.7405375242.
# Iteration 50, inertia 394294.28142220667.
# Iteration 51, inertia 394293.48793287075.
# Iteration 52, inertia 394292.71915394004.
# Iteration 53, inertia 394291.39395799045.
# Iteration 54, inertia 394290.23504039727.
# Iteration 55, inertia 394289.5261202702.
# Iteration 56, inertia 394289.0933399629.
# Iteration 57, inertia 394288.9190375732.
# Iteration 58, inertia 394288.781854306.
# Iteration 59, inertia 394288.6998233855.
# Iteration 60, inertia 394288.5890141381.
# Converged at iteration 60: strict convergence.
# Initialization complete
# Iteration 0, inertia 654080.9495732415.
# Iteration 1, inertia 415689.4038615558.
# Iteration 2, inertia 407218.3541753516.
# Iteration 3, inertia 403323.4567425124.
# Iteration 4, inertia 401091.6637033873.
# Iteration 5, inertia 399573.67904697126.
# Iteration 6, inertia 398397.17163182993.
# Iteration 7, inertia 397607.2379115633.
# Iteration 8, inertia 397019.9503552113.
# Iteration 9, inertia 396580.4330486275.
# Iteration 10, inertia 396195.4039112888.
# Iteration 11, inertia 395758.34008566174.
# Iteration 12, inertia 395416.1639077409.
# Iteration 13, inertia 395126.1821656113.
# Iteration 14, inertia 394847.2700124987.
# Iteration 15, inertia 394599.493582794.
# Iteration 16, inertia 394428.7846999114.
# Iteration 17, inertia 394257.8445338318.
# Iteration 18, inertia 394134.6027831945.
# Iteration 19, inertia 394065.81991386815.
# Iteration 20, inertia 394005.248664.
# Iteration 21, inertia 393933.35042573226.
# Iteration 22, inertia 393885.1759407462.
# Iteration 23, inertia 393832.23320862185.
# Iteration 24, inertia 393750.34620221076.
# Iteration 25, inertia 393646.39478888223.
# Iteration 26, inertia 393522.06488561776.
# Iteration 27, inertia 393332.49220913975.
# Iteration 28, inertia 393093.67461153294.
# Iteration 29, inertia 392842.18565031927.
# Iteration 30, inertia 392594.38866390154.
# Iteration 31, inertia 392415.8386117215.
# Iteration 32, inertia 392319.7168894113.
# Iteration 33, inertia 392261.3045578162.
# Iteration 34, inertia 392227.1721276231.
# Iteration 35, inertia 392208.00048830215.
# Iteration 36, inertia 392196.03991514165.
# Iteration 37, inertia 392188.7615374624.
# Iteration 38, inertia 392183.4536993633.
# Iteration 39, inertia 392176.8982913266.
# Iteration 40, inertia 392172.18952637876.
# Iteration 41, inertia 392167.8457820197.
# Iteration 42, inertia 392163.95572446234.
# Iteration 43, inertia 392158.1356061175.
# Iteration 44, inertia 392153.59373789135.
# Iteration 45, inertia 392149.9864548766.
# Iteration 46, inertia 392146.6871988831.
# Iteration 47, inertia 392144.1044469628.
# Iteration 48, inertia 392140.3190085536.
# Iteration 49, inertia 392137.4460826942.
# Iteration 50, inertia 392135.8314451026.
# Iteration 51, inertia 392134.5851112423.
# Iteration 52, inertia 392133.1377934828.
# Iteration 53, inertia 392132.351434558.
# Iteration 54, inertia 392131.5993033551.
# Iteration 55, inertia 392131.51125922095.
# Iteration 56, inertia 392131.43904246285.
# Converged at iteration 56: strict convergence.
#
# Hoàn thành gom cụm!
# Inertia (tổng bình phương khoảng cách): 392098.97

# %% [markdown]
# ## 5. Ánh xạ cụm với nhãn thực tế

# %%
print(STUDENT)

# Tạo ma trận confusion để ánh xạ cụm với nhãn
def map_clusters_to_labels(cluster_labels, true_labels):
    """
    Ánh xạ các cụm với nhãn thực tế sử dụng Hungarian algorithm
    """
    # Tạo ma trận chi phí
    n_clusters = len(np.unique(cluster_labels))
    n_classes = len(np.unique(true_labels))
    cost_matrix = np.zeros((n_clusters, n_classes))

    for i in range(n_clusters):
        for j in range(n_classes):
            cost_matrix[i, j] = -np.sum((cluster_labels == i) & (true_labels == j))

    # Sử dụng Hungarian algorithm
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    # Tạo mapping
    mapping = {row: col for row, col in zip(row_ind, col_ind)}

    # Áp dụng mapping
    mapped_labels = np.array([mapping[label] for label in cluster_labels])

    return mapped_labels, mapping

mapped_labels, cluster_mapping = map_clusters_to_labels(cluster_labels, y_sample)

print("Ánh xạ cụm -> nhãn:")
for cluster, label in sorted(cluster_mapping.items()):
    print(f"  Cụm {cluster} -> Chữ số {label}")
# Out:
# Dương Võ Anh Tài - 6351071064
# Ánh xạ cụm -> nhãn:
#   Cụm 0 -> Chữ số 2
#   Cụm 1 -> Chữ số 6
#   Cụm 2 -> Chữ số 9
#   Cụm 3 -> Chữ số 1
#   Cụm 4 -> Chữ số 7
#   Cụm 5 -> Chữ số 3
#   Cụm 6 -> Chữ số 4
#   Cụm 7 -> Chữ số 0
#   Cụm 8 -> Chữ số 8
#   Cụm 9 -> Chữ số 5

# %% [markdown]
# ## 6. Đánh giá kết quả gom cụm

# %%
print(STUDENT)

# Tính các metrics
ari = adjusted_rand_score(y_sample, cluster_labels)
nmi = normalized_mutual_info_score(y_sample, cluster_labels)
silhouette = silhouette_score(X_sample, cluster_labels, sample_size=5000)
accuracy = np.mean(mapped_labels == y_sample)

print("=" * 50)
print("KẾT QUẢ ĐÁNH GIÁ GOM CỤM")
print("=" * 50)
print(f"Adjusted Rand Index (ARI): {ari:.4f}")
print(f"Normalized Mutual Information (NMI): {nmi:.4f}")
print(f"Silhouette Score: {silhouette:.4f}")
print(f"Accuracy (sau khi ánh xạ): {accuracy:.4f} ({accuracy*100:.2f}%)")
print("=" * 50)
# Out:
# Dương Võ Anh Tài - 6351071064
# ==================================================
# KẾT QUẢ ĐÁNH GIÁ GOM CỤM
# ==================================================
# Adjusted Rand Index (ARI): 0.3641
# Normalized Mutual Information (NMI): 0.4852
# Silhouette Score: 0.0560
# Accuracy (sau khi ánh xạ): 0.5347 (53.47%)
# ==================================================

# %% [markdown]
# ## 7. Ma trận nhầm lẫn (Confusion Matrix)

# %%
print(STUDENT)

# Tạo confusion matrix
cm = confusion_matrix(y_sample, mapped_labels)

# Vẽ confusion matrix
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=range(10), yticklabels=range(10))
plt.title('Ma trận nhầm lẫn - So sánh Nhãn thực tế vs Nhãn gom cụm', fontsize=14, pad=20)
plt.ylabel('Nhãn thực tế', fontsize=12)
plt.xlabel('Nhãn gom cụm (sau ánh xạ)', fontsize=12)
plt.tight_layout()
plt.show()

# Hiển thị accuracy cho từng chữ số
print("\nĐộ chính xác theo từng chữ số:")
for i in range(10):
    digit_accuracy = cm[i, i] / cm[i, :].sum() if cm[i, :].sum() > 0 else 0
    print(f"  Chữ số {i}: {digit_accuracy:.4f} ({digit_accuracy*100:.2f}%)")
# Out:
# Dương Võ Anh Tài - 6351071064
# Độ chính xác theo từng chữ số:
#   Chữ số 0: 0.7914 (79.14%)
#   Chữ số 1: 0.5255 (52.55%)
#   Chữ số 2: 0.7123 (71.23%)
#   Chữ số 3: 0.6398 (63.98%)
#   Chữ số 4: 0.3934 (39.34%)
#   Chữ số 5: 0.0782 (7.82%)
#   Chữ số 6: 0.8077 (80.77%)
#   Chữ số 7: 0.4388 (43.88%)
#   Chữ số 8: 0.5224 (52.24%)
#   Chữ số 9: 0.4168 (41.68%)

# %% [markdown]
# ## 8. Trực quan hóa kết quả bằng PCA

# %%
print(STUDENT)

# Giảm chiều dữ liệu xuống 2D bằng PCA
print("Đang thực hiện PCA để trực quan hóa...")
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_sample)

print(f"Phương sai được giải thích: {pca.explained_variance_ratio_.sum():.4f}")

# Vẽ kết quả
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Nhãn thực tế
scatter1 = axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=y_sample, cmap='tab10', alpha=0.6, s=10)
axes[0].set_title('Phân bố theo nhãn thực tế', fontsize=14)
axes[0].set_xlabel('PC1', fontsize=12)
axes[0].set_ylabel('PC2', fontsize=12)
plt.colorbar(scatter1, ax=axes[0], label='Chữ số')

# Nhãn gom cụm
scatter2 = axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=mapped_labels, cmap='tab10', alpha=0.6, s=10)
axes[1].set_title('Phân bố theo kết quả gom cụm K-Means', fontsize=14)
axes[1].set_xlabel('PC1', fontsize=12)
axes[1].set_ylabel('PC2', fontsize=12)
plt.colorbar(scatter2, ax=axes[1], label='Chữ số (ánh xạ)')

plt.tight_layout()
plt.show()
# Out:
# Dương Võ Anh Tài - 6351071064
# Đang thực hiện PCA để trực quan hóa...
# Phương sai được giải thích: 0.1689

# %% [markdown]
# ## 9. Hiển thị ví dụ từ mỗi cụm

# %%
print(STUDENT)

# Hiển thị 5 ảnh đại diện từ mỗi cụm
fig, axes = plt.subplots(10, 5, figsize=(12, 24))

for cluster in range(10):
    # Lấy các indices của cụm hiện tại
    cluster_indices = np.where(cluster_labels == cluster)[0]

    # Lấy 5 mẫu ngẫu nhiên
    sample_indices = np.random.choice(cluster_indices, min(5, len(cluster_indices)), replace=False)

    for i, idx in enumerate(sample_indices):
        if hasattr(X_sample, 'iloc'):
            image = X_sample.iloc[idx].values.reshape(28, 28)
        else:
            image = X_sample[idx].reshape(28, 28)

        axes[cluster, i].imshow(image, cmap='gray')
        true_label = y_sample.iloc[idx] if hasattr(y_sample, 'iloc') else y_sample[idx]
        axes[cluster, i].set_title(f'Nhãn: {true_label}', fontsize=9)
        axes[cluster, i].axis('off')

    # Thêm label cho cụm
    axes[cluster, 0].set_ylabel(f'Cụm {cluster}\n(→{cluster_mapping[cluster]})',
                                fontsize=10, rotation=0, labelpad=40, va='center')

plt.suptitle('Mẫu đại diện từ mỗi cụm', fontsize=16, y=0.995)
plt.tight_layout()
plt.show()
# Out:
# Dương Võ Anh Tài - 6351071064

# %% [markdown]
# ## 10. Phân tích các lỗi gom cụm

# %%
print(STUDENT)

# Tìm các mẫu bị phân loại sai
misclassified = mapped_labels != y_sample
n_misclassified = np.sum(misclassified)

print(f"Số lượng mẫu bị gom cụm sai: {n_misclassified}/{len(y_sample)} ({n_misclassified/len(y_sample)*100:.2f}%)")

# Hiển thị 10 ví dụ bị gom cụm sai
if n_misclassified > 0:
    misclassified_indices = np.where(misclassified)[0]
    sample_misclassified = np.random.choice(misclassified_indices, min(10, n_misclassified), replace=False)

    fig, axes = plt.subplots(2, 5, figsize=(14, 6))
    for i, idx in enumerate(sample_misclassified):
        ax = axes[i // 5, i % 5]
        if hasattr(X_sample, 'iloc'):
            image = X_sample.iloc[idx].values.reshape(28, 28)
        else:
            image = X_sample[idx].reshape(28, 28)

        ax.imshow(image, cmap='gray')
        true_label = y_sample.iloc[idx] if hasattr(y_sample, 'iloc') else y_sample[idx]
        pred_label = mapped_labels[idx]
        ax.set_title(f'Thực: {true_label}, Dự đoán: {pred_label}', fontsize=10, color='red')
        ax.axis('off')

    plt.suptitle('Ví dụ về các mẫu bị gom cụm sai', fontsize=14, y=1.00)
    plt.tight_layout()
    plt.show()
# Out:
# Dương Võ Anh Tài - 6351071064
# Số lượng mẫu bị gom cụm sai: 4653/10000 (46.53%)

# %% [markdown]
# ## 11. Tổng kết

# %%
print(STUDENT)

print("\n" + "="*60)
print("TỔNG KẾT KẾT QUẢ GOM CỤM K-MEANS TRÊN DỮ LIỆU MNIST")
print("="*60)
print(f"\nSố mẫu sử dụng: {n_samples}")
print(f"Số cụm (K): {n_clusters}")
print(f"\nCác chỉ số đánh giá:")
print(f"  - Độ chính xác: {accuracy*100:.2f}%")
print(f"  - Adjusted Rand Index: {ari:.4f}")
print(f"  - Normalized Mutual Information: {nmi:.4f}")
print(f"  - Silhouette Score: {silhouette:.4f}")
print(f"\nKết luận:")
print(f"  K-Means đã gom cụm {'tốt' if accuracy > 0.7 else 'khá' if accuracy > 0.5 else 'cần cải thiện'} ")
print(f"  trên dữ liệu MNIST với độ chính xác {accuracy*100:.2f}%.")
print(f"  Thuật toán có thể phân biệt được các chữ số khác nhau")
print(f"  dựa trên đặc trưng hình ảnh mà không cần nhãn.")
print("="*60)
# Out:
# Dương Võ Anh Tài - 6351071064
#
# ============================================================
# TỔNG KẾT KẾT QUẢ GOM CỤM K-MEANS TRÊN DỮ LIỆU MNIST
# ============================================================
#
# Số mẫu sử dụng: 10000
# Số cụm (K): 10
#
# Các chỉ số đánh giá:
#   - Độ chính xác: 53.47%
#   - Adjusted Rand Index: 0.3641
#   - Normalized Mutual Information: 0.4852
#   - Silhouette Score: 0.0560
#
# Kết luận:
#   K-Means đã gom cụm khá
#   trên dữ liệu MNIST với độ chính xác 53.47%.
#   Thuật toán có thể phân biệt được các chữ số khác nhau
#   dựa trên đặc trưng hình ảnh mà không cần nhãn.
# ============================================================
